# %% [markdown]
# <a href="https://www.kaggle.com/code/shuvojitdas/daily-covid-19-interactive-plots?scriptVersionId=133513828" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
from bs4 import BeautifulSoup as soup
from urllib.request import Request, urlopen
from datetime import date, datetime
fname = 'https://www.worldometers.info/coronavirus/'
req = Request(fname, headers={'User-Agent': 'Mozilla/5.0'})
webpage = urlopen(req)
page_soup = soup(webpage, "html.parser")

# %%
today = datetime.now()
now_str = "%s %d, %d at %d:%s" % (date.today().strftime("%b"), today.day, today.year, today.hour, '0'+str(today.minute) if today.minute < 10 else str(today.minute))
containers = page_soup.findAll("div", {"class": "maincounter-number"})
print("As of %s UTC, there have been %s total COVID-19 cases." % (now_str, containers[0].findAll("span")[0].text.replace(' ', '')))
# Out:
# As of Jun 14, 2023 at 6:13 UTC, there have been 690,329,203 total COVID-19 cases.

# %%
#-----General------#
import numpy as np
import pandas as pd
import os
import sys
import math
import random

#-----Plotting-----#
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import plotly.express as px
import plotly.offline as py
py.init_notebook_mode(connected=True)
import seaborn as sns
from pandas_profiling import ProfileReport

#-----Utility-----#
import itertools
import warnings
warnings.filterwarnings("ignore")
import re
import gc
from bs4 import BeautifulSoup as soup
from urllib.request import Request, urlopen
from datetime import date, datetime

LOOK_AT = 5 # Controls how many bars the user can see in the bar graph
AT_LEAST = 50 # Controls what rank a country must be in terms of total cases to be shown on the bar graph
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# <h1> Web Scraping Foundation </h1>

# %%
fname = 'https://www.worldometers.info/coronavirus/#countries'
req = Request(fname, headers={'User-Agent': 'Mozilla/5.0'})
webpage = urlopen(req)
page_soup = soup(webpage, "html.parser")
today = datetime.now()
today_str = "%s %d, %d" % (date.today().strftime("%b"), today.day, today.year)
yesterday_str = "%s %d, %d" % (date.today().strftime("%b"), today.day-1, today.year)
clean = True

# %%
print("This version of the notebook is being run on %s." % today_str)
# Out:
# This version of the notebook is being run on Jun 14, 2023.

# %%
table = page_soup.findAll("table", {"id": "main_table_countries_yesterday"})
containers = table[0].findAll("tr", {"style": ""})
del containers[0]

all_data = []
for country in containers:
    country_data = []
    country_container = country.findAll("td")
    if country_container[1].text == 'China':
        continue
    for i in range(1, len(country_container)):
        final_feature = country_container[i].text
        if clean:
            if i != 1 and i != len(country_container)-1:
                final_feature = final_feature.replace(',', '')
                if final_feature.find('+') != -1:
                    final_feature = final_feature.replace('+', '')
                    final_feature = float(final_feature)
                elif final_feature.find('-') != -1:
                    final_feature = final_feature.replace('-', '')
                    final_feature = float(final_feature)*-1
        if final_feature == 'N/A':
            final_feature = 0
        elif final_feature == '' or final_feature == ' ':
            final_feature = -1 #None
        country_data.append(final_feature)
    all_data.append(country_data)

# %%
df = pd.DataFrame(all_data)
df = df.drop([i for i in range(15, len(all_data[0]))], axis=1) # Get rid of unnecessary data

# %% [markdown]
# On the <a href="https://www.worldometers.info/coronavirus/"> worldometers website</a>, the category "New Recovered" doesn't appear; however, based on the numbers, we can interpolate a certain column of data to be that.

# %%
column_labels = ["Country", "Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical",
                "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population", "Continent"]
df.columns = column_labels

# %% [markdown]
# <h1> What Countries are not present in the Analysis? </h1>
#
# For some reason, there are some countries that are not included when scraping the webpage.

# %%
country_labels = page_soup.findAll("a", {"class": "mt_a"})
c_label = []
for country in country_labels:
    c_label.append(country.text)
c_label = set(c_label)

not_counted = []
sorted_countries = set(df['Country']) #Increase computational speed
for country in c_label:
    if country not in sorted_countries:
        not_counted.append(country)

# %%
print(not_counted)
# Out:
# ['Saint Kitts and Nevis', 'Slovakia', 'Argentina', 'Peru', 'Western Sahara', 'DPRK', 'Netherlands', 'Eritrea', 'Vatican City', 'China', 'Falkland Islands', 'Syria', 'Cyprus', 'Taiwan', 'Liechtenstein', 'Sao Tome and Principe']

# %% [markdown]
# <h1> Final Processing </h1>
#
# Here, we will convert all the numerical data into np.int64 data type, and add some other features that may be particularly useful.

# %%
for label in df.columns:
    if label != 'Country' and label != 'Continent':
        df[label] = pd.to_numeric(df[label])

# %%
df['%Inc Cases'] = df['New Cases']/df['Total Cases']*100
df['%Inc Deaths'] = df['New Deaths']/df['Total Deaths']*100
df['%Inc Recovered'] = df['New Recovered']/df['Total Recovered']*100

# %%
pd.options.display.max_rows = None
df
# Out:
#                     Country  Total Cases  New Cases  Total Deaths  New Deaths  \
# 0                     World    690329169    17249.0       6891075       206.0
# 1                       USA    107194316     3387.0       1166818        37.0
# 2                     India     44993080      292.0        531892        -1.0
# 3                    France     40116548     2631.0        167508        28.0
# 4                   Germany     38428685       -1.0        174352        -1.0
# 5                    Brazil     37639324     1915.0        703399        15.0
# 6                     Japan     33803572       -1.0         74694        -1.0
# 7                  S. Korea     31904667       -1.0         34893        -1.0
# 8                     Italy     25879984       -1.0        190625        -1.0
# 9                        UK     24618436       -1.0        226278        -1.0
# 10                   Russia     22949243     6785.0        399339       113.0
# 11                   Turkey     17232066       -1.0        102174        -1.0
# 12                    Spain     13890555       -1.0        121416        -1.0
# 13                Australia     11653091       -1.0         21258        -1.0
# 14                  Vietnam     11618184      199.0         43206        -1.0
# 15                   Mexico      7627255       -1.0        334240        -1.0
# 16                     Iran      7612234       23.0        146289         1.0
# 17                Indonesia      6810417      181.0        161830         4.0
# 18                   Poland      6517448       53.0        119622        -1.0
# 19                 Colombia      6369916       -1.0        142780        -1.0
# 20                   Greece      6086580       -1.0         37014        -1.0
# 21                  Austria      6079272      150.0         22518        -1.0
# 22                 Portugal      5590047       -1.0         26804        -1.0
# 23                  Ukraine      5556030       -1.0        112394        -1.0
# 24                    Chile      5287875       13.0         64497        -1.0
# 25                 Malaysia      5108586       -1.0         37110        -1.0
# 26                   Israel      4826780       -1.0         12540        -1.0
# 27                  Belgium      4800312       -1.0         34360        -1.0
# 28                 Thailand      4747752       -1.0         34232        -1.0
# 29                   Canada      4684456       -1.0         52751        -1.0
# 30                  Czechia      4642442       31.0         42806        -1.0
# 31              Switzerland      4405938       -1.0         14452        -1.0
# 32              Philippines      4156176      418.0         66481        -1.0
# 33             South Africa      4076463       -1.0        102595        -1.0
# 34                  Romania      3406169       -1.0         68217        -1.0
# 35                  Denmark      3182099       18.0          8733        -1.0
# 36                Hong Kong      2904315       -1.0         13819        -1.0
# 37                   Sweden      2710983       -1.0         24409        -1.0
# 38                   Serbia      2542941       -1.0         18057        -1.0
# 39                Singapore      2481404       -1.0          1727        -1.0
# 40                     Iraq      2465545       -1.0         25375        -1.0
# 41              New Zealand      2397065       -1.0          4448        -1.0
# 179  Australia/Oceania   -0.006212    -5.882353       -0.006219
# 180      North America   -0.006345    -1.351351       -0.006380
# 181             Africa   -0.006373    -0.529101       -0.006482
# 182             Africa   -0.006507    -0.884956       -0.006579
# 183             Africa   -0.007920    -0.268817       -0.008204
# 184      North America   -0.008128    -1.587302       -0.071480
# 185  Australia/Oceania   -0.008320    -7.142857       -0.008350
# 186      North America   -0.008354    -4.761905       -0.036219
# 187               Asia   -0.008372    -0.046318       -0.010960
# 188      North America   -0.008560    -2.631579       -0.009546
# 189      North America   -0.009049    -1.086957       -0.009170
# 190             Africa   -0.010069    -0.320513       -0.011249
# 191               Asia    2.482521    -0.819672       -0.028678
# 192      North America   -0.010383    -0.806452       -0.010534
# 193             Africa   -0.010401    -0.564972       -0.011199
# 194             Africa   -0.010978    -0.621118       -0.011187
# 195      North America   -0.010982    -0.684932       -0.011168
# 196             Africa   -0.012361    -0.338983       -0.012849
# 197             Africa   -0.012883    -0.793651             NaN
# 198             Africa   -0.012985    -0.515464       -0.020517
# 199      North America   -0.013689    -1.562500             NaN
# 200  Australia/Oceania    0.126103   -50.000000        0.336606
# 201      North America   -0.015179    -2.631579       -0.015316
# 202  Australia/Oceania   -0.016636   -11.111111       -0.016667
# 203      North America   -0.018202   -16.666667             NaN
# 204  Australia/Oceania   -0.018543  -100.000000       -0.018702
# 205  Australia/Oceania   -0.019853    -4.166667       -0.036996
# 206      North America   -0.025615    -8.333333       -0.025780
# 207  Australia/Oceania   -0.028169   -12.500000       -0.228311
# 208      North America   -0.028969   -50.000000       -0.040833
# 209  Australia/Oceania   -0.035651   100.000000      100.000000
# 210             Africa   -0.046168   100.000000      -50.000000
# 211      North America   -0.071276   -12.500000       -0.072674
# 212  Australia/Oceania   -0.121951   100.000000       -0.122699
# 213  Australia/Oceania  -20.000000   100.000000      100.000000
# 214                All    0.002499     0.002989        0.004858

# %% [markdown]
# <h1> Export </h1>
#
# Feel free to use this data for your own purposes/visualizations. If you don't want to fork the notebook, you can download the csv file in the output section of this notebook.

# %%
EXPORT = True
today = datetime.now()
if EXPORT:
    today = date.today()
    df.to_csv(f'covid_stats_{today.year}_{today.month}_{today.day-1}')
    print("Dataset is %.2f MB" % (df.memory_usage(deep=True).sum()/1000000))
# Out:
# Dataset is 0.06 MB

# %% [markdown]
# <h1 class="alert alert-block alert-info" style="text-align:center; font-size:24px" id="general">General Visualizations<a class="anchor-link" href="https://www.kaggle.com/ironicninja/covid-19-every-day/notebook#general">¶</a></h1>

# %%
cases_ser = df[["Total Recovered", "Active Cases", "Total Deaths"]].loc[0]
cases_df = pd.DataFrame(cases_ser).reset_index()
cases_df.columns = ['Type', 'Total']
cases_df['Percentage'] = np.round(100*cases_df['Total']/np.sum(cases_df['Total']), 2)
cases_df['Virus'] = ['COVID-19' for i in range(len(cases_df))]

fig = px.bar(cases_df, x='Virus', y='Percentage', color='Type', hover_data=['Total'])
fig.update_layout(title={'text': f"Total Number of Cases, Recoveries, and Deaths on {yesterday_str}", 'x': 0.5,
                         'xanchor': 'center', 'font': {'size': 20}}, yaxis_title="Percentage", xaxis_title="")
fig.show()
# Out:
# <div>                            <div id="eb74efe2-846f-40dc-b420-0584b2a4b733" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("eb74efe2-846f-40dc-b420-0584b2a4b733")) {                    Plotly.newPlot(                        "eb74efe2-846f-40dc-b420-0584b2a4b733",                        [{"alignmentgroup": "True", "customdata": [[662774499.0]], "hovertemplate": "Type=Total Recovered<br>Virus=%{x}<br>Percentage=%{y}<br>Total=%{customdata[0]}<extra></extra>", "legendgroup": "Total Recovered", "marker": {"color": "#636efa"}, "name": "Total Recovered", "offsetgroup": "Total Recovered", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["COVID-19"], "xaxis": "x", "y": [96.01], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[20663595.0]], "hovertemplate": "Type=Active Cases<br>Virus=%{x}<br>Percentage=%{y}<br>Total=%{customdata[0]}<extra></extra>", "legendgroup": "Active Cases", "marker": {"color": "#EF553B"}, "name": "Active Cases", "offsetgroup": "Active Cases", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["COVID-19"], "xaxis": "x", "y": [2.99], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[6891075.0]], "hovertemplate": "Type=Total Deaths<br>Virus=%{x}<br>Percentage=%{y}<br>Total=%{customdata[0]}<extra></extra>", "legendgroup": "Total Deaths", "marker": {"color": "#00cc96"}, "name": "Total Deaths", "offsetgroup": "Total Deaths", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["COVID-19"], "xaxis": "x", "y": [1.0], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"title": {"text": "Type"}, "tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d ...

# %%
new_ser = df[["New Cases", "New Recovered", "New Deaths"]].loc[0]
new_df = pd.DataFrame(new_ser).reset_index()
new_df.columns = ['Type', 'Total']
new_df['Percentage'] = np.round(100*new_df['Total']/np.sum(new_df['Total']), 2)
new_df['Virus'] = ['COVID-19' for i in range(len(new_df))]

fig = px.bar(new_df, x='Virus', y='Percentage', color='Type', hover_data=['Total'])
fig.update_layout(title={'text': f"New Cases, Recoveries, and Deaths on {yesterday_str}", 'x': 0.5,
                         'xanchor': 'center', 'font': {'size': 20}}, yaxis_title="Percentage", xaxis_title="")
fig.show()
# Out:
# <div>                            <div id="82f883d8-67a1-44a9-bba7-8f9688292fdc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("82f883d8-67a1-44a9-bba7-8f9688292fdc")) {                    Plotly.newPlot(                        "82f883d8-67a1-44a9-bba7-8f9688292fdc",                        [{"alignmentgroup": "True", "customdata": [[17249.0]], "hovertemplate": "Type=New Cases<br>Virus=%{x}<br>Percentage=%{y}<br>Total=%{customdata[0]}<extra></extra>", "legendgroup": "New Cases", "marker": {"color": "#636efa"}, "name": "New Cases", "offsetgroup": "New Cases", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["COVID-19"], "xaxis": "x", "y": [34.74], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[32196.0]], "hovertemplate": "Type=New Recovered<br>Virus=%{x}<br>Percentage=%{y}<br>Total=%{customdata[0]}<extra></extra>", "legendgroup": "New Recovered", "marker": {"color": "#EF553B"}, "name": "New Recovered", "offsetgroup": "New Recovered", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["COVID-19"], "xaxis": "x", "y": [64.84], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[206.0]], "hovertemplate": "Type=New Deaths<br>Virus=%{x}<br>Percentage=%{y}<br>Total=%{customdata[0]}<extra></extra>", "legendgroup": "New Deaths", "marker": {"color": "#00cc96"}, "name": "New Deaths", "offsetgroup": "New Deaths", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["COVID-19"], "xaxis": "x", "y": [0.41], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"title": {"text": "Type"}, "tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0,  ...

# %%
pinc_ser = np.round(df[["%Inc Cases", "%Inc Recovered", "%Inc Deaths"]].loc[0], 2)
pinc_df = pd.DataFrame(pinc_ser)
pinc_df.columns = ["Percentage"]

fig = go.Figure()
fig.add_trace(go.Bar(x=pinc_df.index, y=pinc_df['Percentage'], marker_color=["yellow", "green", "red"]))
fig.update_layout(title={'text': f"New Cases, Recoveries, and Deaths on {yesterday_str}", 'x': 0.5,
                         'xanchor': 'center', 'font': {'size': 20}}, yaxis_title="Percentage", xaxis_title="")
fig.show()
# Out:
# <div>                            <div id="3b407d3e-8abe-4961-a83b-42d884312a51" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3b407d3e-8abe-4961-a83b-42d884312a51")) {                    Plotly.newPlot(                        "3b407d3e-8abe-4961-a83b-42d884312a51",                        [{"marker": {"color": ["yellow", "green", "red"]}, "type": "bar", "x": ["%Inc Cases", "%Inc Recovered", "%Inc Deaths"], "y": [0.0, 0.0, 0.0]}],                        {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type ...

# %% [markdown]
# <h1 class="alert alert-block alert-info" style="text-align:center; font-size:24px" id="continent">By Continent<a class="anchor-link" href="https://www.kaggle.com/ironicninja/covid-19-every-day/notebook#continent">¶</a></h1>

# %%
continent_df = df.groupby('Continent').sum().drop('All')
continent_df = continent_df.reset_index()
continent_df
# Out:
#            Continent  Total Cases  New Cases  Total Deaths  New Deaths  \
# 0             Africa     12808992      -44.0        258597       -55.0
# 1               Asia    201625298     1511.0       1518295       -31.0
# 2  Australia/Oceania     14468050      -10.0         28557       -20.0
# 3             Europe    239054787     9845.0       2019775       107.0
# 4      North America    126834117     3710.0       1635613         0.0
# 5      South America     54216430     2059.0       1005650         5.0
#
#    Total Recovered  New Recovered  Active Cases  Serious/Critical  \
# 0         10951790          -44.0      382959.0               515
# 1        146910433         2550.0     2120237.0              1254
# 2         14246022            8.0       64709.0                86
# 3        235012338        21052.0     1741190.0              1835
# 4        122662105         8332.0     1631475.0              1194
# 5         51519176          127.0      819351.0              1394
#
#    Tot Cases/1M  Deaths/1M  Total Tests   Tests/1M  Population  %Inc Cases  \
# 0     2462573.0    18154.0    110936458   10784682  1402212660   -0.188770
# 1     6787595.0    32805.0   2196208276   83889708  3192417913    2.515400
# 2     4708469.0     9115.0     91665928   21201908    43470408  -20.155148
# 3    17401272.0   119330.0   2799265397  209058273   724833011    0.063154
# 4     8729277.0    57831.0   1318602004   99220604   598087045   -0.240667
# 5     1701614.0    23687.0    170022797    9622001   357996462    0.040992
#
#    %Inc Deaths  %Inc Recovered
# 0    86.170393      -50.147911
# 1    -8.664908        0.118353
# 2    95.324725      199.824891
# 3    -9.247138        0.215298
# 4  -110.667309       -0.270097
# 5    -0.428809        0.025145

# %%
cases_vis_list = ['Total Cases', 'Active Cases', 'New Cases', 'Serious/Critical', 'Tot Cases/1M']
deaths_vis_list = ['Total Deaths', 'New Deaths', 'Deaths/1M']
recovered_vis_list = ['Total Recovered', 'New Recovered']
tests_vis_list = ['Total Tests', 'Tests/1M']
essentials = [['Total Cases', 'Active Cases', 'New Cases'], ['Total Deaths', 'New Deaths'], ['Total Recovered', 'New Recovered']]

# %%
def continent_visualization(vis_list):
    for label in vis_list:
        c_df = continent_df[['Continent', label]]
        c_df['Percentage'] = np.round(100*c_df[label]/np.sum(c_df[label]), 2)
        c_df['Virus'] = ['COVID-19' for i in range(len(c_df))]
        
        fig = px.bar(c_df, x='Virus', y='Percentage', color='Continent', hover_data=[label])
        fig.update_layout(title={'text': f"{label} at the end of {yesterday_str}", 'x': 0.5,
                                 'xanchor': 'center', 'font': {'size': 20}}, yaxis_title="Percentage", xaxis_title="")
        fig.show()
        gc.collect()

# %%
continent_visualization(cases_vis_list)
# Out:
# <div>                            <div id="c5812c0f-b106-4f9a-b387-8343c712805b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c5812c0f-b106-4f9a-b387-8343c712805b")) {                    Plotly.newPlot(                        "c5812c0f-b106-4f9a-b387-8343c712805b",                        [{"alignmentgroup": "True", "customdata": [[12808992]], "hovertemplate": "Continent=Africa<br>Virus=%{x}<br>Percentage=%{y}<br>Total Cases=%{customdata[0]}<extra></extra>", "legendgroup": "Africa", "marker": {"color": "#636efa"}, "name": "Africa", "offsetgroup": "Africa", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["COVID-19"], "xaxis": "x", "y": [1.97], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[201625298]], "hovertemplate": "Continent=Asia<br>Virus=%{x}<br>Percentage=%{y}<br>Total Cases=%{customdata[0]}<extra></extra>", "legendgroup": "Asia", "marker": {"color": "#EF553B"}, "name": "Asia", "offsetgroup": "Asia", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["COVID-19"], "xaxis": "x", "y": [31.07], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[14468050]], "hovertemplate": "Continent=Australia/Oceania<br>Virus=%{x}<br>Percentage=%{y}<br>Total Cases=%{customdata[0]}<extra></extra>", "legendgroup": "Australia/Oceania", "marker": {"color": "#00cc96"}, "name": "Australia/Oceania", "offsetgroup": "Australia/Oceania", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["COVID-19"], "xaxis": "x", "y": [2.23], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[239054787]], "hovertemplate": "Continent=Europe<br>Virus=%{x}<br>Percentage=%{y}<br>Total Cases=%{customdata[0]}<extra></extra>", "legendgroup": "Europe", "marker": {"color": "#ab63fa"}, "name": "Europe", "offsetgroup": "Europe", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["COVID-19"], "xaxis": "x", "y": [36.83], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[126834117]], "hovertemplate": "Continent=North America<br>Virus=%{x}<br>Percentage=%{y}<br>Total Cases=%{customdata[0]}<extra></extra>", "legendgroup": "North America", "marker": {"color": "#FFA15A"}, "name": "North America", "offsetgroup": "North America", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["COVID-19"], "xaxis": "x", "y": [19.54], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[54216430]], "hovertemplate": "Continent=South America<br>Virus=%{x}<br>Percentage=%{y}<br>Total Cases=%{customdata[0]}<extra></extra>", "legendgroup": "South America", "marker": {"color": "#19d3f3"}, "name": "South America", "offsetgroup": "South America", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["COVID-19"], "xaxis": "x", "y": [8.35], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"title": {"text": "Continent"}, "tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.111111111111111 ...
# <div>                            <div id="2dd0f050-3d40-47e0-8426-90b9d7f88edd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2dd0f050-3d40-47e0-8426-90b9d7f88edd")) {                    Plotly.newPlot(                        "2dd0f050-3d40-47e0-8426-90b9d7f88edd",                        [{"alignmentgroup": "True", "customdata": [[382959.0]], "hovertemplate": "Continent=Africa<br>Virus=%{x}<br>Percentage=%{y}<br>Active Cases=%{customdata[0]}<extra></extra>", "legendgroup": "Africa", "marker": {"color": "#636efa"}, "name": "Africa", "offsetgroup": "Africa", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["COVID-19"], "xaxis": "x", "y": [5.67], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[2120237.0]], "hovertemplate": "Continent=Asia<br>Virus=%{x}<br>Percentage=%{y}<br>Active Cases=%{customdata[0]}<extra></extra>", "legendgroup": "Asia", "marker": {"color": "#EF553B"}, "name": "Asia", "offsetgroup": "Asia", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["COVID-19"], "xaxis": "x", "y": [31.36], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[64709.0]], "hovertemplate": "Continent=Australia/Oceania<br>Virus=%{x}<br>Percentage=%{y}<br>Active Cases=%{customdata[0]}<extra></extra>", "legendgroup": "Australia/Oceania", "marker": {"color": "#00cc96"}, "name": "Australia/Oceania", "offsetgroup": "Australia/Oceania", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["COVID-19"], "xaxis": "x", "y": [0.96], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[1741190.0]], "hovertemplate": "Continent=Europe<br>Virus=%{x}<br>Percentage=%{y}<br>Active Cases=%{customdata[0]}<extra></extra>", "legendgroup": "Europe", "marker": {"color": "#ab63fa"}, "name": "Europe", "offsetgroup": "Europe", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["COVID-19"], "xaxis": "x", "y": [25.76], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[1631475.0]], "hovertemplate": "Continent=North America<br>Virus=%{x}<br>Percentage=%{y}<br>Active Cases=%{customdata[0]}<extra></extra>", "legendgroup": "North America", "marker": {"color": "#FFA15A"}, "name": "North America", "offsetgroup": "North America", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["COVID-19"], "xaxis": "x", "y": [24.13], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[819351.0]], "hovertemplate": "Continent=South America<br>Virus=%{x}<br>Percentage=%{y}<br>Active Cases=%{customdata[0]}<extra></extra>", "legendgroup": "South America", "marker": {"color": "#19d3f3"}, "name": "South America", "offsetgroup": "South America", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["COVID-19"], "xaxis": "x", "y": [12.12], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"title": {"text": "Continent"}, "tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.111111111 ...
# <div>                            <div id="7865a25f-a84d-4041-9058-71e923d6c688" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7865a25f-a84d-4041-9058-71e923d6c688")) {                    Plotly.newPlot(                        "7865a25f-a84d-4041-9058-71e923d6c688",                        [{"alignmentgroup": "True", "customdata": [[-44.0]], "hovertemplate": "Continent=Africa<br>Virus=%{x}<br>Percentage=%{y}<br>New Cases=%{customdata[0]}<extra></extra>", "legendgroup": "Africa", "marker": {"color": "#636efa"}, "name": "Africa", "offsetgroup": "Africa", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["COVID-19"], "xaxis": "x", "y": [-0.26], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[1511.0]], "hovertemplate": "Continent=Asia<br>Virus=%{x}<br>Percentage=%{y}<br>New Cases=%{customdata[0]}<extra></extra>", "legendgroup": "Asia", "marker": {"color": "#EF553B"}, "name": "Asia", "offsetgroup": "Asia", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["COVID-19"], "xaxis": "x", "y": [8.85], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[-10.0]], "hovertemplate": "Continent=Australia/Oceania<br>Virus=%{x}<br>Percentage=%{y}<br>New Cases=%{customdata[0]}<extra></extra>", "legendgroup": "Australia/Oceania", "marker": {"color": "#00cc96"}, "name": "Australia/Oceania", "offsetgroup": "Australia/Oceania", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["COVID-19"], "xaxis": "x", "y": [-0.06], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[9845.0]], "hovertemplate": "Continent=Europe<br>Virus=%{x}<br>Percentage=%{y}<br>New Cases=%{customdata[0]}<extra></extra>", "legendgroup": "Europe", "marker": {"color": "#ab63fa"}, "name": "Europe", "offsetgroup": "Europe", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["COVID-19"], "xaxis": "x", "y": [57.67], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[3710.0]], "hovertemplate": "Continent=North America<br>Virus=%{x}<br>Percentage=%{y}<br>New Cases=%{customdata[0]}<extra></extra>", "legendgroup": "North America", "marker": {"color": "#FFA15A"}, "name": "North America", "offsetgroup": "North America", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["COVID-19"], "xaxis": "x", "y": [21.73], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[2059.0]], "hovertemplate": "Continent=South America<br>Virus=%{x}<br>Percentage=%{y}<br>New Cases=%{customdata[0]}<extra></extra>", "legendgroup": "South America", "marker": {"color": "#19d3f3"}, "name": "South America", "offsetgroup": "South America", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["COVID-19"], "xaxis": "x", "y": [12.06], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"title": {"text": "Continent"}, "tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.222222222 ...
# <div>                            <div id="aaefe659-888a-47f7-a655-e3545b785aed" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("aaefe659-888a-47f7-a655-e3545b785aed")) {                    Plotly.newPlot(                        "aaefe659-888a-47f7-a655-e3545b785aed",                        [{"alignmentgroup": "True", "customdata": [[515]], "hovertemplate": "Continent=Africa<br>Virus=%{x}<br>Percentage=%{y}<br>Serious/Critical=%{customdata[0]}<extra></extra>", "legendgroup": "Africa", "marker": {"color": "#636efa"}, "name": "Africa", "offsetgroup": "Africa", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["COVID-19"], "xaxis": "x", "y": [8.2], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[1254]], "hovertemplate": "Continent=Asia<br>Virus=%{x}<br>Percentage=%{y}<br>Serious/Critical=%{customdata[0]}<extra></extra>", "legendgroup": "Asia", "marker": {"color": "#EF553B"}, "name": "Asia", "offsetgroup": "Asia", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["COVID-19"], "xaxis": "x", "y": [19.97], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[86]], "hovertemplate": "Continent=Australia/Oceania<br>Virus=%{x}<br>Percentage=%{y}<br>Serious/Critical=%{customdata[0]}<extra></extra>", "legendgroup": "Australia/Oceania", "marker": {"color": "#00cc96"}, "name": "Australia/Oceania", "offsetgroup": "Australia/Oceania", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["COVID-19"], "xaxis": "x", "y": [1.37], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[1835]], "hovertemplate": "Continent=Europe<br>Virus=%{x}<br>Percentage=%{y}<br>Serious/Critical=%{customdata[0]}<extra></extra>", "legendgroup": "Europe", "marker": {"color": "#ab63fa"}, "name": "Europe", "offsetgroup": "Europe", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["COVID-19"], "xaxis": "x", "y": [29.23], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[1194]], "hovertemplate": "Continent=North America<br>Virus=%{x}<br>Percentage=%{y}<br>Serious/Critical=%{customdata[0]}<extra></extra>", "legendgroup": "North America", "marker": {"color": "#FFA15A"}, "name": "North America", "offsetgroup": "North America", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["COVID-19"], "xaxis": "x", "y": [19.02], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[1394]], "hovertemplate": "Continent=South America<br>Virus=%{x}<br>Percentage=%{y}<br>Serious/Critical=%{customdata[0]}<extra></extra>", "legendgroup": "South America", "marker": {"color": "#19d3f3"}, "name": "South America", "offsetgroup": "South America", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["COVID-19"], "xaxis": "x", "y": [22.2], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"title": {"text": "Continent"}, "tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111 ...
# <div>                            <div id="58832812-e073-4961-a986-227f085f2a8a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("58832812-e073-4961-a986-227f085f2a8a")) {                    Plotly.newPlot(                        "58832812-e073-4961-a986-227f085f2a8a",                        [{"alignmentgroup": "True", "customdata": [[2462573.0]], "hovertemplate": "Continent=Africa<br>Virus=%{x}<br>Percentage=%{y}<br>Tot Cases/1M=%{customdata[0]}<extra></extra>", "legendgroup": "Africa", "marker": {"color": "#636efa"}, "name": "Africa", "offsetgroup": "Africa", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["COVID-19"], "xaxis": "x", "y": [5.89], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[6787595.0]], "hovertemplate": "Continent=Asia<br>Virus=%{x}<br>Percentage=%{y}<br>Tot Cases/1M=%{customdata[0]}<extra></extra>", "legendgroup": "Asia", "marker": {"color": "#EF553B"}, "name": "Asia", "offsetgroup": "Asia", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["COVID-19"], "xaxis": "x", "y": [16.24], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[4708469.0]], "hovertemplate": "Continent=Australia/Oceania<br>Virus=%{x}<br>Percentage=%{y}<br>Tot Cases/1M=%{customdata[0]}<extra></extra>", "legendgroup": "Australia/Oceania", "marker": {"color": "#00cc96"}, "name": "Australia/Oceania", "offsetgroup": "Australia/Oceania", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["COVID-19"], "xaxis": "x", "y": [11.27], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[17401272.0]], "hovertemplate": "Continent=Europe<br>Virus=%{x}<br>Percentage=%{y}<br>Tot Cases/1M=%{customdata[0]}<extra></extra>", "legendgroup": "Europe", "marker": {"color": "#ab63fa"}, "name": "Europe", "offsetgroup": "Europe", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["COVID-19"], "xaxis": "x", "y": [41.64], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[8729277.0]], "hovertemplate": "Continent=North America<br>Virus=%{x}<br>Percentage=%{y}<br>Tot Cases/1M=%{customdata[0]}<extra></extra>", "legendgroup": "North America", "marker": {"color": "#FFA15A"}, "name": "North America", "offsetgroup": "North America", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["COVID-19"], "xaxis": "x", "y": [20.89], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[1701614.0]], "hovertemplate": "Continent=South America<br>Virus=%{x}<br>Percentage=%{y}<br>Tot Cases/1M=%{customdata[0]}<extra></extra>", "legendgroup": "South America", "marker": {"color": "#19d3f3"}, "name": "South America", "offsetgroup": "South America", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["COVID-19"], "xaxis": "x", "y": [4.07], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"title": {"text": "Continent"}, "tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111 ...

# %%
continent_visualization(deaths_vis_list)
# Out:
# <div>                            <div id="ebf78ba1-b6bc-4336-aeaa-346fc105f7ca" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ebf78ba1-b6bc-4336-aeaa-346fc105f7ca")) {                    Plotly.newPlot(                        "ebf78ba1-b6bc-4336-aeaa-346fc105f7ca",                        [{"alignmentgroup": "True", "customdata": [[258597]], "hovertemplate": "Continent=Africa<br>Virus=%{x}<br>Percentage=%{y}<br>Total Deaths=%{customdata[0]}<extra></extra>", "legendgroup": "Africa", "marker": {"color": "#636efa"}, "name": "Africa", "offsetgroup": "Africa", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["COVID-19"], "xaxis": "x", "y": [4.0], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[1518295]], "hovertemplate": "Continent=Asia<br>Virus=%{x}<br>Percentage=%{y}<br>Total Deaths=%{customdata[0]}<extra></extra>", "legendgroup": "Asia", "marker": {"color": "#EF553B"}, "name": "Asia", "offsetgroup": "Asia", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["COVID-19"], "xaxis": "x", "y": [23.48], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[28557]], "hovertemplate": "Continent=Australia/Oceania<br>Virus=%{x}<br>Percentage=%{y}<br>Total Deaths=%{customdata[0]}<extra></extra>", "legendgroup": "Australia/Oceania", "marker": {"color": "#00cc96"}, "name": "Australia/Oceania", "offsetgroup": "Australia/Oceania", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["COVID-19"], "xaxis": "x", "y": [0.44], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[2019775]], "hovertemplate": "Continent=Europe<br>Virus=%{x}<br>Percentage=%{y}<br>Total Deaths=%{customdata[0]}<extra></extra>", "legendgroup": "Europe", "marker": {"color": "#ab63fa"}, "name": "Europe", "offsetgroup": "Europe", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["COVID-19"], "xaxis": "x", "y": [31.23], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[1635613]], "hovertemplate": "Continent=North America<br>Virus=%{x}<br>Percentage=%{y}<br>Total Deaths=%{customdata[0]}<extra></extra>", "legendgroup": "North America", "marker": {"color": "#FFA15A"}, "name": "North America", "offsetgroup": "North America", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["COVID-19"], "xaxis": "x", "y": [25.29], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[1005650]], "hovertemplate": "Continent=South America<br>Virus=%{x}<br>Percentage=%{y}<br>Total Deaths=%{customdata[0]}<extra></extra>", "legendgroup": "South America", "marker": {"color": "#19d3f3"}, "name": "South America", "offsetgroup": "South America", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["COVID-19"], "xaxis": "x", "y": [15.55], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"title": {"text": "Continent"}, "tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#4 ...
# <div>                            <div id="7bf238c1-94eb-4149-875f-715f2aa33d41" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7bf238c1-94eb-4149-875f-715f2aa33d41")) {                    Plotly.newPlot(                        "7bf238c1-94eb-4149-875f-715f2aa33d41",                        [{"alignmentgroup": "True", "customdata": [[-55.0]], "hovertemplate": "Continent=Africa<br>Virus=%{x}<br>Percentage=%{y}<br>New Deaths=%{customdata[0]}<extra></extra>", "legendgroup": "Africa", "marker": {"color": "#636efa"}, "name": "Africa", "offsetgroup": "Africa", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["COVID-19"], "xaxis": "x", "y": [-916.67], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[-31.0]], "hovertemplate": "Continent=Asia<br>Virus=%{x}<br>Percentage=%{y}<br>New Deaths=%{customdata[0]}<extra></extra>", "legendgroup": "Asia", "marker": {"color": "#EF553B"}, "name": "Asia", "offsetgroup": "Asia", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["COVID-19"], "xaxis": "x", "y": [-516.67], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[-20.0]], "hovertemplate": "Continent=Australia/Oceania<br>Virus=%{x}<br>Percentage=%{y}<br>New Deaths=%{customdata[0]}<extra></extra>", "legendgroup": "Australia/Oceania", "marker": {"color": "#00cc96"}, "name": "Australia/Oceania", "offsetgroup": "Australia/Oceania", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["COVID-19"], "xaxis": "x", "y": [-333.33], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[107.0]], "hovertemplate": "Continent=Europe<br>Virus=%{x}<br>Percentage=%{y}<br>New Deaths=%{customdata[0]}<extra></extra>", "legendgroup": "Europe", "marker": {"color": "#ab63fa"}, "name": "Europe", "offsetgroup": "Europe", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["COVID-19"], "xaxis": "x", "y": [1783.33], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[0.0]], "hovertemplate": "Continent=North America<br>Virus=%{x}<br>Percentage=%{y}<br>New Deaths=%{customdata[0]}<extra></extra>", "legendgroup": "North America", "marker": {"color": "#FFA15A"}, "name": "North America", "offsetgroup": "North America", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["COVID-19"], "xaxis": "x", "y": [0.0], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[5.0]], "hovertemplate": "Continent=South America<br>Virus=%{x}<br>Percentage=%{y}<br>New Deaths=%{customdata[0]}<extra></extra>", "legendgroup": "South America", "marker": {"color": "#19d3f3"}, "name": "South America", "offsetgroup": "South America", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["COVID-19"], "xaxis": "x", "y": [83.33], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"title": {"text": "Continent"}, "tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222 ...
# <div>                            <div id="5ccc36e9-ba01-4161-be53-34f88a97bc3f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5ccc36e9-ba01-4161-be53-34f88a97bc3f")) {                    Plotly.newPlot(                        "5ccc36e9-ba01-4161-be53-34f88a97bc3f",                        [{"alignmentgroup": "True", "customdata": [[18154.0]], "hovertemplate": "Continent=Africa<br>Virus=%{x}<br>Percentage=%{y}<br>Deaths/1M=%{customdata[0]}<extra></extra>", "legendgroup": "Africa", "marker": {"color": "#636efa"}, "name": "Africa", "offsetgroup": "Africa", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["COVID-19"], "xaxis": "x", "y": [6.96], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[32805.0]], "hovertemplate": "Continent=Asia<br>Virus=%{x}<br>Percentage=%{y}<br>Deaths/1M=%{customdata[0]}<extra></extra>", "legendgroup": "Asia", "marker": {"color": "#EF553B"}, "name": "Asia", "offsetgroup": "Asia", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["COVID-19"], "xaxis": "x", "y": [12.57], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[9115.0]], "hovertemplate": "Continent=Australia/Oceania<br>Virus=%{x}<br>Percentage=%{y}<br>Deaths/1M=%{customdata[0]}<extra></extra>", "legendgroup": "Australia/Oceania", "marker": {"color": "#00cc96"}, "name": "Australia/Oceania", "offsetgroup": "Australia/Oceania", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["COVID-19"], "xaxis": "x", "y": [3.49], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[119330.0]], "hovertemplate": "Continent=Europe<br>Virus=%{x}<br>Percentage=%{y}<br>Deaths/1M=%{customdata[0]}<extra></extra>", "legendgroup": "Europe", "marker": {"color": "#ab63fa"}, "name": "Europe", "offsetgroup": "Europe", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["COVID-19"], "xaxis": "x", "y": [45.73], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[57831.0]], "hovertemplate": "Continent=North America<br>Virus=%{x}<br>Percentage=%{y}<br>Deaths/1M=%{customdata[0]}<extra></extra>", "legendgroup": "North America", "marker": {"color": "#FFA15A"}, "name": "North America", "offsetgroup": "North America", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["COVID-19"], "xaxis": "x", "y": [22.16], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[23687.0]], "hovertemplate": "Continent=South America<br>Virus=%{x}<br>Percentage=%{y}<br>Deaths/1M=%{customdata[0]}<extra></extra>", "legendgroup": "South America", "marker": {"color": "#19d3f3"}, "name": "South America", "offsetgroup": "South America", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["COVID-19"], "xaxis": "x", "y": [9.08], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"title": {"text": "Continent"}, "tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.222 ...

# %%
continent_visualization(tests_vis_list)
# Out:
# <div>                            <div id="73120f90-9f0a-4fbc-ad7f-b6dac0e3c9ee" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("73120f90-9f0a-4fbc-ad7f-b6dac0e3c9ee")) {                    Plotly.newPlot(                        "73120f90-9f0a-4fbc-ad7f-b6dac0e3c9ee",                        [{"alignmentgroup": "True", "customdata": [[110936458]], "hovertemplate": "Continent=Africa<br>Virus=%{x}<br>Percentage=%{y}<br>Total Tests=%{customdata[0]}<extra></extra>", "legendgroup": "Africa", "marker": {"color": "#636efa"}, "name": "Africa", "offsetgroup": "Africa", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["COVID-19"], "xaxis": "x", "y": [1.66], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[2196208276]], "hovertemplate": "Continent=Asia<br>Virus=%{x}<br>Percentage=%{y}<br>Total Tests=%{customdata[0]}<extra></extra>", "legendgroup": "Asia", "marker": {"color": "#EF553B"}, "name": "Asia", "offsetgroup": "Asia", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["COVID-19"], "xaxis": "x", "y": [32.84], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[91665928]], "hovertemplate": "Continent=Australia/Oceania<br>Virus=%{x}<br>Percentage=%{y}<br>Total Tests=%{customdata[0]}<extra></extra>", "legendgroup": "Australia/Oceania", "marker": {"color": "#00cc96"}, "name": "Australia/Oceania", "offsetgroup": "Australia/Oceania", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["COVID-19"], "xaxis": "x", "y": [1.37], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[2799265397]], "hovertemplate": "Continent=Europe<br>Virus=%{x}<br>Percentage=%{y}<br>Total Tests=%{customdata[0]}<extra></extra>", "legendgroup": "Europe", "marker": {"color": "#ab63fa"}, "name": "Europe", "offsetgroup": "Europe", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["COVID-19"], "xaxis": "x", "y": [41.86], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[1318602004]], "hovertemplate": "Continent=North America<br>Virus=%{x}<br>Percentage=%{y}<br>Total Tests=%{customdata[0]}<extra></extra>", "legendgroup": "North America", "marker": {"color": "#FFA15A"}, "name": "North America", "offsetgroup": "North America", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["COVID-19"], "xaxis": "x", "y": [19.72], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[170022797]], "hovertemplate": "Continent=South America<br>Virus=%{x}<br>Percentage=%{y}<br>Total Tests=%{customdata[0]}<extra></extra>", "legendgroup": "South America", "marker": {"color": "#19d3f3"}, "name": "South America", "offsetgroup": "South America", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["COVID-19"], "xaxis": "x", "y": [2.54], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"title": {"text": "Continent"}, "tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111 ...
# <div>                            <div id="21b85a70-7309-4abd-a70e-6523c9802ca0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("21b85a70-7309-4abd-a70e-6523c9802ca0")) {                    Plotly.newPlot(                        "21b85a70-7309-4abd-a70e-6523c9802ca0",                        [{"alignmentgroup": "True", "customdata": [[10784682]], "hovertemplate": "Continent=Africa<br>Virus=%{x}<br>Percentage=%{y}<br>Tests/1M=%{customdata[0]}<extra></extra>", "legendgroup": "Africa", "marker": {"color": "#636efa"}, "name": "Africa", "offsetgroup": "Africa", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["COVID-19"], "xaxis": "x", "y": [2.49], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[83889708]], "hovertemplate": "Continent=Asia<br>Virus=%{x}<br>Percentage=%{y}<br>Tests/1M=%{customdata[0]}<extra></extra>", "legendgroup": "Asia", "marker": {"color": "#EF553B"}, "name": "Asia", "offsetgroup": "Asia", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["COVID-19"], "xaxis": "x", "y": [19.34], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[21201908]], "hovertemplate": "Continent=Australia/Oceania<br>Virus=%{x}<br>Percentage=%{y}<br>Tests/1M=%{customdata[0]}<extra></extra>", "legendgroup": "Australia/Oceania", "marker": {"color": "#00cc96"}, "name": "Australia/Oceania", "offsetgroup": "Australia/Oceania", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["COVID-19"], "xaxis": "x", "y": [4.89], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[209058273]], "hovertemplate": "Continent=Europe<br>Virus=%{x}<br>Percentage=%{y}<br>Tests/1M=%{customdata[0]}<extra></extra>", "legendgroup": "Europe", "marker": {"color": "#ab63fa"}, "name": "Europe", "offsetgroup": "Europe", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["COVID-19"], "xaxis": "x", "y": [48.19], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[99220604]], "hovertemplate": "Continent=North America<br>Virus=%{x}<br>Percentage=%{y}<br>Tests/1M=%{customdata[0]}<extra></extra>", "legendgroup": "North America", "marker": {"color": "#FFA15A"}, "name": "North America", "offsetgroup": "North America", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["COVID-19"], "xaxis": "x", "y": [22.87], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[9622001]], "hovertemplate": "Continent=South America<br>Virus=%{x}<br>Percentage=%{y}<br>Tests/1M=%{customdata[0]}<extra></extra>", "legendgroup": "South America", "marker": {"color": "#19d3f3"}, "name": "South America", "offsetgroup": "South America", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["COVID-19"], "xaxis": "x", "y": [2.22], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"title": {"text": "Continent"}, "tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.222 ...

# %%
def continent_visualization2(index, label, log_scale=False):
    c_df = continent_df[['Continent'] + essentials[index]]
    
    fig = px.bar(c_df, x="Continent", y=essentials[index], log_y=log_scale)
    log_str = "- log scale" if log_scale else ""
    fig.update_layout(title={'text': f"{label} at the end of {yesterday_str} {log_str}", 'x': 0.5,
                         'xanchor': 'center', 'font': {'size': 20}}, yaxis_title=label, xaxis_title="")
    
    fig.show()
    gc.collect()

# %%
continent_visualization2(0, "Total Cases", log_scale=True)
# Out:
# <div>                            <div id="fc7bc8e8-8a57-4a58-a62e-f69affebe95e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fc7bc8e8-8a57-4a58-a62e-f69affebe95e")) {                    Plotly.newPlot(                        "fc7bc8e8-8a57-4a58-a62e-f69affebe95e",                        [{"alignmentgroup": "True", "hovertemplate": "variable=Total Cases<br>Continent=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "Total Cases", "marker": {"color": "#636efa"}, "name": "Total Cases", "offsetgroup": "Total Cases", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Africa", "Asia", "Australia/Oceania", "Europe", "North America", "South America"], "xaxis": "x", "y": [12808992.0, 201625298.0, 14468050.0, 239054787.0, 126834117.0, 54216430.0], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "variable=Active Cases<br>Continent=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "Active Cases", "marker": {"color": "#EF553B"}, "name": "Active Cases", "offsetgroup": "Active Cases", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Africa", "Asia", "Australia/Oceania", "Europe", "North America", "South America"], "xaxis": "x", "y": [382959.0, 2120237.0, 64709.0, 1741190.0, 1631475.0, 819351.0], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "variable=New Cases<br>Continent=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "New Cases", "marker": {"color": "#00cc96"}, "name": "New Cases", "offsetgroup": "New Cases", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Africa", "Asia", "Australia/Oceania", "Europe", "North America", "South America"], "xaxis": "x", "y": [-44.0, 1511.0, -10.0, 9845.0, 3710.0, 2059.0], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"title": {"text": "variable"}, "tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778,  ...

# %%
continent_visualization2(1, "Deaths", log_scale=True)
# Out:
# <div>                            <div id="dc7bfc0e-a6d9-4b20-9ba9-aa68ef4a4e69" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dc7bfc0e-a6d9-4b20-9ba9-aa68ef4a4e69")) {                    Plotly.newPlot(                        "dc7bfc0e-a6d9-4b20-9ba9-aa68ef4a4e69",                        [{"alignmentgroup": "True", "hovertemplate": "variable=Total Deaths<br>Continent=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "Total Deaths", "marker": {"color": "#636efa"}, "name": "Total Deaths", "offsetgroup": "Total Deaths", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Africa", "Asia", "Australia/Oceania", "Europe", "North America", "South America"], "xaxis": "x", "y": [258597.0, 1518295.0, 28557.0, 2019775.0, 1635613.0, 1005650.0], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "variable=New Deaths<br>Continent=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "New Deaths", "marker": {"color": "#EF553B"}, "name": "New Deaths", "offsetgroup": "New Deaths", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Africa", "Asia", "Australia/Oceania", "Europe", "North America", "South America"], "xaxis": "x", "y": [-55.0, -31.0, -20.0, 107.0, 0.0, 5.0], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"title": {"text": "variable"}, "tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0. ...

# %%
continent_visualization2(2, "Recoveries", log_scale=True)
# Out:
# <div>                            <div id="d75437ae-67d5-476f-ad03-32581245b7d4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d75437ae-67d5-476f-ad03-32581245b7d4")) {                    Plotly.newPlot(                        "d75437ae-67d5-476f-ad03-32581245b7d4",                        [{"alignmentgroup": "True", "hovertemplate": "variable=Total Recovered<br>Continent=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "Total Recovered", "marker": {"color": "#636efa"}, "name": "Total Recovered", "offsetgroup": "Total Recovered", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Africa", "Asia", "Australia/Oceania", "Europe", "North America", "South America"], "xaxis": "x", "y": [10951790.0, 146910433.0, 14246022.0, 235012338.0, 122662105.0, 51519176.0], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "variable=New Recovered<br>Continent=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "New Recovered", "marker": {"color": "#EF553B"}, "name": "New Recovered", "offsetgroup": "New Recovered", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Africa", "Asia", "Australia/Oceania", "Europe", "North America", "South America"], "xaxis": "x", "y": [-44.0, 2550.0, 8.0, 21052.0, 8332.0, 127.0], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"title": {"text": "variable"}, "tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed79 ...

# %% [markdown]
# <h1 class="alert alert-block alert-info" style="text-align:center; font-size:24px" id="countries">By Countries<a class="anchor-link" href="https://www.kaggle.com/ironicninja/covid-19-every-day/notebook#countries">¶</a></h1>

# %%
df = df.drop([len(df)-1])
country_df = df.drop([0])

# %%
country_l = country_df.columns[1:14]

fig = go.Figure()
c = 0
for i in country_df.index:
    if c < LOOK_AT:
        fig.add_trace(go.Bar(name=country_df['Country'][i], x=country_l, y=country_df.loc[i][1:14]))
    else:
        break
    c += 1
    
fig.update_layout(title={'text': f'{LOOK_AT} Countries with Most COVID Cases on %s' % yesterday_str, 'x': 0.5,
                         'xanchor': 'center', 'font': {'size': 20}}, yaxis_title="Percentage", yaxis_type="log", xaxis_tickangle=-90)
fig.show()
# Out:
# <div>                            <div id="36c42461-22b9-49b6-9070-3328a7f20395" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("36c42461-22b9-49b6-9070-3328a7f20395")) {                    Plotly.newPlot(                        "36c42461-22b9-49b6-9070-3328a7f20395",                        [{"name": "USA", "type": "bar", "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [107194316, 3387.0, 1166818, 37.0, 105334686, 4521.0, 692812.0, 841, 320169.0, 3485.0, 1180560088, 3526110, 334805269]}, {"name": "India", "type": "bar", "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [44993080, 292.0, 531892, -1.0, 44459040, 220.0, 2148.0, 0, 31986.0, 378.0, 930797975, 661721, 1406631776]}, {"name": "France", "type": "bar", "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [40116548, 2631.0, 167508, 28.0, 39898866, 4905.0, 50174.0, 869, 611677.0, 2554.0, 271490188, 4139547, 65584518]}, {"name": "Germany", "type": "bar", "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [38428685, -1.0, 174352, -1.0, 38240600, -1.0, 13733.0, 0, 458119.0, 2078.0, 122332384, 1458359, 83883596]}, {"name": "Brazil", "type": "bar", "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [37639324, 1915.0, 703399, 15.0, 36249161, -1.0, 686764.0, 0, 174779.0, 3266.0, 63776166, 296146, 215353593]}],                        {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.111111111111111 ...

# %%
inc_l = country_df.columns[15:]
inc_df = country_df.sort_values("%Inc Cases", ascending=False)
fig = go.Figure()
c = 0
for i in inc_df.index:
    if i > AT_LEAST:
        continue
    if c < LOOK_AT:
        fig.add_trace(go.Bar(name=country_df['Country'][i], x=inc_l, y=inc_df.loc[i][15:]))
    else:
        break
    c += 1
    
fig.update_layout(title={'text': f'{LOOK_AT} Countries with Highest Increase in COVID Cases on %s' % yesterday_str, 'x': 0.5,
                         'xanchor': 'center', 'font': {'size': 20}}, yaxis_title="Percentage", xaxis_tickangle=0)
fig.show()
# Out:
# <div>                            <div id="923d15ba-c85f-44c3-ab57-299e134e04c9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("923d15ba-c85f-44c3-ab57-299e134e04c9")) {                    Plotly.newPlot(                        "923d15ba-c85f-44c3-ab57-299e134e04c9",                        [{"name": "Russia", "type": "bar", "x": ["%Inc Cases", "%Inc Deaths", "%Inc Recovered"], "y": [0.02956524535471606, 0.02829676039655531, 0.04481605652915319]}, {"name": "Philippines", "type": "bar", "x": ["%Inc Cases", "%Inc Deaths", "%Inc Recovered"], "y": [0.01005732192284446, -0.0015041891668296204, 0.026252657438118124]}, {"name": "France", "type": "bar", "x": ["%Inc Cases", "%Inc Deaths", "%Inc Recovered"], "y": [0.006558390816677448, 0.016715619552498985, 0.01229358247926144]}, {"name": "Brazil", "type": "bar", "x": ["%Inc Cases", "%Inc Deaths", "%Inc Recovered"], "y": [0.005087764062925253, 0.0021325023208733592, -2.758684538933191e-06]}, {"name": "USA", "type": "bar", "x": ["%Inc Cases", "%Inc Deaths", "%Inc Recovered"], "y": [0.003159682459282636, 0.003171017245191624, 0.004292033490278786]}],                        {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "# ...

# %%
country_labels = country_df.columns[1:14]

def country_visualization(continent):
    buttons_list = []
    base_list = [False for i in range(len(country_df))]
    c = 0
    for i in country_df.index:
        if country_df.loc[i]['Continent'] != continent:
            continue
        tmp_list = base_list.copy()
        tmp_list[c] = True
        c += 1
        buttons_list.append(dict(
                    args=[{"visible": tmp_list}],
                    label=country_df.loc[i]['Country'],
                    method="update"
                ))


    fig = go.Figure()
    c = 0
    for i in country_df.index:
        if country_df.loc[i]['Continent'] != continent:
            continue
        fig.add_trace(go.Bar(name=country_df.loc[i]['Country'], x=country_labels, y=country_df.loc[i][1:14], visible=False if c != 0 else True))
        c += 1

    fig.update_layout(
        updatemenus=[
            dict(
                buttons=buttons_list,
                direction="down",
                pad={"r": 10, "t": 10},
                showactive=True,
                x=0.1,
                xanchor="left",
                y=1.1,
                yanchor="top"
            ),
        ]
    )

    fig.update_layout(title={'text': '%s COVID-19 Cases Search on %s' % (continent, yesterday_str), 'x': 0.5,
                         'xanchor': 'center', 'font': {'size': 20}}, yaxis_type="log", xaxis_tickangle=-90)
    fig.show()

# %% [markdown]
# <h1 id="country-search">COVID-19 Cases Search</h1>

# %%
country_visualization('Africa')
# Out:
# <div>                            <div id="2d240457-0da9-41a5-bd9f-3977b6f2255e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2d240457-0da9-41a5-bd9f-3977b6f2255e")) {                    Plotly.newPlot(                        "2d240457-0da9-41a5-bd9f-3977b6f2255e",                        [{"name": "South Africa", "type": "bar", "visible": true, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [4076463, -1.0, 102595, -1.0, 3912506, -1.0, 61362.0, 192, 67095.0, 1689.0, 26795090, 441027, 60756135]}, {"name": "Morocco", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [1274180, -1.0, 16297, -1.0, 1256151, -1.0, 1732.0, 3, 33733.0, 431.0, 13001033, 344191, 37772756]}, {"name": "Tunisia", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [1153361, -1.0, 29423, -1.0, 0, 0.0, 0.0, 44, 95741.0, 2442.0, 5013383, 416164, 12046656]}, {"name": "Egypt", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [516023, -1.0, 24613, -1.0, 442182, -1.0, 49228.0, 122, 4861.0, 232.0, 3693367, 34792, 106156692]}, {"name": "Libya", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [507264, -1.0, 6437, -1.0, 500826, -1.0, 1.0, -1, 72047.0, 914.0, 2483848, 352782, 7040745]}, {"name": "Ethiopia", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [500919, 1.0, 7574, -1.0, 488134, -1.0, 5211.0, -1, 4146.0, 63.0, 5556642, 45994, 120812698]}, {"name": "R\u00e9union", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [486588, -1.0, 921, -1.0, 418572, -1.0, 67095.0, 10, 535854.0, 1014.0, 1603660, 1766027, 908061]}, {"name": "Zambia", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [345058, -1.0, 4058, -1.0, 340454, -1.0, 546.0, -1, 17722.0, 208.0, 4087410, 209931, 19470234]}, {"name": "Kenya", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y":
"type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [1114549, 17.0, 8530, -1.0, 1105861, 18.0, 158.0, -1, 98583.0, 754.0, 14345279, 1268859, 11305652]}, {"name": "Panama", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [1040230, -1.0, 8624, -1.0, 1030855, -1.0, 751.0, 16, 233919.0, 1939.0, 7697189, 1730886, 4446964]}, {"name": "Dominican Republic", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [661176, -1.0, 4384, -1.0, 644785, -1.0, 12007.0, 4, 59800.0, 397.0, 3740928, 338350, 11056370]}, {"name": "Honduras", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [472619, -1.0, 11116, -1.0, 0, 0.0, 0.0, 105, 46239.0, 1088.0, 1660662, 162472, 10221247]}, {"name": "Martinique", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Re ...

# %%
country_visualization('South America')
# Out:
# <div>                            <div id="3bd139ac-53c1-4a0f-84ff-d68c0a0c2a56" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3bd139ac-53c1-4a0f-84ff-d68c0a0c2a56")) {                    Plotly.newPlot(                        "3bd139ac-53c1-4a0f-84ff-d68c0a0c2a56",                        [{"name": "Brazil", "type": "bar", "visible": true, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [37639324, 1915.0, 703399, 15.0, 36249161, -1.0, 686764.0, 0, 174779.0, 3266.0, 63776166, 296146, 215353593]}, {"name": "Colombia", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [6369916, -1.0, 142780, -1.0, 6190683, -1.0, 36453.0, 342, 123657.0, 2772.0, 36951507, 717327, 51512762]}, {"name": "Chile", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [5287875, 13.0, 64497, -1.0, 5223324, 26.0, 54.0, 13, 274692.0, 3350.0, 49745630, 2584162, 19250195]}, {"name": "Bolivia", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [1200630, 117.0, 22386, -1.0, 1169571, 88.0, 8673.0, 220, 100114.0, 1867.0, 2710261, 225993, 11992656]}, {"name": "Ecuador", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [1062275, -1.0, 36019, -1.0, 1025747, -1.0, 509.0, 759, 58646.0, 1989.0, 3082403, 170173, 18113361]}, {"name": "Uruguay", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [1038774, -1.0, 7634, -1.0, 1030944, -1.0, 196.0, 18, 297131.0, 2184.0, 6114822, 1749083, 3496016]}, {"name": "Paraguay", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [811051, -1.0, 19955, -1.0, 0, 0.0, 0.0, 7, 111014.0, 2731.0, 2657506, 363751, 7305843]}, {"name": "Venezuela", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [552695, -1.0, 5856, -1.0, 546537, -1.0, 302.0, 31, 18885.0, 200.0, 3359014, 114771, 29266991]}, {"name": "French Guiana", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [98041, -1.0, 420, -1.0, 11254, -1.0, 86367.0, 6, 312065.0, 1337.0, 651257, 2072951, 314169]}, {"name": "Suriname", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases ...

# %%
bar_list = []
for i in country_df.index:
    bar_list.append(go.Bar(name=country_df['Country'][i], y=[country_df['Total Cases'][i]]))
    
fig = go.Figure(data=bar_list)
fig.update_layout(title={'text': 'Stacked Bar Chart of All Countries COVID-19 Cases on %s' % yesterday_str, 'x': 0.5,
                         'xanchor': 'center', 'font': {'size': 20}}, barmode='stack', height=1200)
fig.show()
# Out:
# <div>                            <div id="24965ca6-541b-46ad-a00e-af6dff302b90" class="plotly-graph-div" style="height:1200px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("24965ca6-541b-46ad-a00e-af6dff302b90")) {                    Plotly.newPlot(                        "24965ca6-541b-46ad-a00e-af6dff302b90",                        [{"name": "USA", "type": "bar", "y": [107194316]}, {"name": "India", "type": "bar", "y": [44993080]}, {"name": "France", "type": "bar", "y": [40116548]}, {"name": "Germany", "type": "bar", "y": [38428685]}, {"name": "Brazil", "type": "bar", "y": [37639324]}, {"name": "Japan", "type": "bar", "y": [33803572]}, {"name": "S. Korea", "type": "bar", "y": [31904667]}, {"name": "Italy", "type": "bar", "y": [25879984]}, {"name": "UK", "type": "bar", "y": [24618436]}, {"name": "Russia", "type": "bar", "y": [22949243]}, {"name": "Turkey", "type": "bar", "y": [17232066]}, {"name": "Spain", "type": "bar", "y": [13890555]}, {"name": "Australia", "type": "bar", "y": [11653091]}, {"name": "Vietnam", "type": "bar", "y": [11618184]}, {"name": "Mexico", "type": "bar", "y": [7627255]}, {"name": "Iran", "type": "bar", "y": [7612234]}, {"name": "Indonesia", "type": "bar", "y": [6810417]}, {"name": "Poland", "type": "bar", "y": [6517448]}, {"name": "Colombia", "type": "bar", "y": [6369916]}, {"name": "Greece", "type": "bar", "y": [6086580]}, {"name": "Austria", "type": "bar", "y": [6079272]}, {"name": "Portugal", "type": "bar", "y": [5590047]}, {"name": "Ukraine", "type": "bar", "y": [5556030]}, {"name": "Chile", "type": "bar", "y": [5287875]}, {"name": "Malaysia", "type": "bar", "y": [5108586]}, {"name": "Israel", "type": "bar", "y": [4826780]}, {"name": "Belgium", "type": "bar", "y": [4800312]}, {"name": "Thailand", "type": "bar", "y": [4747752]}, {"name": "Canada", "type": "bar", "y": [4684456]}, {"name": "Czechia", "type": "bar", "y": [4642442]}, {"name": "Switzerland", "type": "bar", "y": [4405938]}, {"name": "Philippines", "type": "bar", "y": [4156176]}, {"name": "South Africa", "type": "bar", "y": [4076463]}, {"name": "Romania", "type": "bar", "y": [3406169]}, {"name": "Denmark", "type": "bar", "y": [3182099]}, {"name": "Hong Kong", "type": "bar", "y": [2904315]}, {"name": "Sweden", "type": "bar", "y": [2710983]}, {"name": "Serbia", "type": "bar", "y": [2542941]}, {"name": "Singapore", "type": "bar", "y": [2481404]}, {"name": "Iraq", "type": "bar", "y": [2465545]}, {"name": "New Zealand", "type": "bar", "y": [2397065]}, {"name": "Hungary", "type": "bar", "y": [2202990]}, {"name": "Bangladesh", "type": "bar", "y": [2039911]}, {"name": "Georgia", "type": "bar", "y": [1843707]}, {"name": "Jordan", "type": "bar", "y": [1746997]}, {"name": "Ireland", "type": "bar", "y": [1712938]}, {"name": "Pakistan", "type": "bar", "y": [1581097]}, {"name": "Norway", "type": "bar", "y": [1485102]}, {"name": "Finland", "type": "bar", "y": [1480896]}, {"name": "Kazakhstan", "type": "bar", "y": [1411831]}, {"name": "Slovenia", "type": "bar", "y": [1344135]}, {"name": "Lithuania", "type": "bar", "y": [1320970]}, {"name": "Bulgaria", "type": "bar", "y": [1308414]}, {"name": "Morocco", "type": "bar", "y": [1274180]}, {"name": "Croatia", "type": "bar", "y": [1273907]}, {"name": "Guatemala", "type": "bar", "y": [1255565]}, {"name": "Lebanon", "type": "bar", "y": [1238411]}, {"name": "Costa Rica", "type": "bar", "y": [1233482]}, {"name": "Bolivia", "type": "bar", "y": [1200630]}, {"name": "Tunisia", "type": "bar", "y": [1153361]}, {"name": "Cuba", "type": "bar", "y": [1114549]}, {"name": "UAE", "type": "bar", "y": [1067030]}, {"name": "Ecuador", "type": "bar", "y": [1062275]}, {"name": "Panama", "type": "bar", "y": [1040230]}, {"name": "Uruguay", "type": "bar", "y": [1038774]}, {"name": "Mongolia", "type": "bar", "y": [1010034]}, {"name": "Nepal", "t ...

ealand", "Hungary", "Bangladesh", "Georgia", "Jordan", "Ireland", "Pakistan", "Norway", "Finland", "Kazakhstan", "Slovenia", "Lithuania", "Bulgaria", "Morocco", "Croatia", "Guatemala", "Lebanon", "Costa Rica", "Bolivia", "Tunisia", "Cuba", "UAE", "Ecuador", "Panama", "Uruguay", "Mongolia", "Nepal", "Belarus", "Latvia", "Saudi Arabia", "Azerbaijan", "Paraguay", "Bahrain", "Sri Lanka", "Kuwait", "Dominican Republic", "Myanmar", "Palestine", "Moldova", "Estonia", "Venezuela", "Egypt", "Qatar", "Libya", "Ethiopia", "R\u00e9union", "Honduras", "Armenia", "Bosnia and Herzegovina", "Oman", "North Macedonia", "Zambia", "Kenya", "Albania", "Botswana", "Luxembourg", "Brunei ", "Montenegro", "Algeria", "Nigeria", "Zimbabwe", "Uzbekistan", "Mozambique", "Martinique", "Afghanistan", "Laos", "Iceland", "Kyrgyzstan", "Guadeloupe", "El Salvador", "Trinidad and Tobago", "Maldives", "Ghana", "Namibia", "Uganda", "Jamaica", "Cambodia", "Rwanda", "Cameroon", "Malta", "Barbados", "Angola", "Channel Islands", "French Guiana", "DRC", "Sen ...

# %% [markdown]
# <h1 id="choropleth"> Choropleth Visualizations </h1>

# %%
country_abbrev = {
'Afghanistan': 'AFG',
 'Albania': 'ALB',
 'Algeria': 'DZA',
 'American Samoa': 'ASM',
 'Andorra': 'AND',
 'Angola': 'AGO',
 'Anguilla': 'AIA',
 'Antigua and Barbuda': 'ATG',
 'Argentina': 'ARG',
 'Armenia': 'ARM',
 'Aruba': 'ABW',
 'Australia': 'AUS',
 'Austria': 'AUT',
 'Azerbaijan': 'AZE',
 'Bahamas, The': 'BHM',
 'Bahrain': 'BHR',
 'Bangladesh': 'BGD',
 'Barbados': 'BRB',
 'Belarus': 'BLR',
 'Belgium': 'BEL',
 'Belize': 'BLZ',
 'Benin': 'BEN',
 'Bermuda': 'BMU',
 'Bhutan': 'BTN',
 'Bolivia': 'BOL',
 'Bosnia and Herzegovina': 'BIH',
 'Botswana': 'BWA',
 'Brazil': 'BRA',
 'British Virgin Islands': 'VGB',
 'Brunei': 'BRN',
 'Bulgaria': 'BGR',
 'Burkina Faso': 'BFA',
 'Burma': 'MMR',
 'Burundi': 'BDI',
 'Cabo Verde': 'CPV',
 'Cambodia': 'KHM',
 'Cameroon': 'CMR',
 'Canada': 'CAN',
 'Cayman Islands': 'CYM',
 'Central African Republic': 'CAF',
 'Chad': 'TCD',
 'Chile': 'CHL',
 'China': 'CHN',
 'Colombia': 'COL',
 'Comoros': 'COM',
 'Congo, Democratic Republic of the': 'COD',
 'Congo, Republic of the': 'COG',
 'Cook Islands': 'COK',
 'Costa Rica': 'CRI',
 "Cote d'Ivoire": 'CIV',
 'Croatia': 'HRV',
 'Cuba': 'CUB',
 'Curacao': 'CUW',
 'Cyprus': 'CYP',
 'Czech Republic': 'CZE',
    'Czechia': 'CZE',
 'Denmark': 'DNK',
 'Djibouti': 'DJI',
 'Dominica': 'DMA',
 'Dominican Republic': 'DOM',
 'Ecuador': 'ECU',
 'Egypt': 'EGY',
 'El Salvador': 'SLV',
 'Equatorial Guinea': 'GNQ',
 'Eritrea': 'ERI',
 'Estonia': 'EST',
 'Ethiopia': 'ETH',
 'Falkland Islands (Islas Malvinas)': 'FLK',
 'Faroe Islands': 'FRO',
 'Fiji': 'FJI',
 'Finland': 'FIN',
 'France': 'FRA',
 'French Polynesia': 'PYF',
 'Gabon': 'GAB',
 'Gambia, The': 'GMB',
 'Georgia': 'GEO',
 'Germany': 'DEU',
 'Ghana': 'GHA',
 'Gibraltar': 'GIB',
 'Greece': 'GRC',
 'Greenland': 'GRL',
 'Grenada': 'GRD',
 'Guam': 'GUM',
 'Guatemala': 'GTM',
 'Guernsey': 'GGY',
 'Guinea-Bissau': 'GNB',
 'Guinea': 'GIN',
 'Guyana': 'GUY',
 'Haiti': 'HTI',
 'Honduras': 'HND',
 'Hong Kong': 'HKG',
 'Hungary': 'HUN',
 'Iceland': 'ISL',
 'India': 'IND',
 'Indonesia': 'IDN',
 'Iran': 'IRN',
 'Iraq': 'IRQ',
 'Ireland': 'IRL',
 'Isle of Man': 'IMN',
 'Israel': 'ISR',
 'Italy': 'ITA',
 'Jamaica': 'JAM',
 'Japan': 'JPN',
 'Jersey': 'JEY',
 'Jordan': 'JOR',
 'Kazakhstan': 'KAZ',
 'Kenya': 'KEN',
 'Kiribati': 'KIR',
 'Korea, North': 'PRK',
 'Korea, South': 'KOR',
 'Kosovo': 'KSV',
 'Kuwait': 'KWT',
 'Kyrgyzstan': 'KGZ',
 'Laos': 'LAO',
 'Latvia': 'LVA',
 'Lebanon': 'LBN',
 'Lesotho': 'LSO',
 'Liberia': 'LBR',
 'Libya': 'LBY',
 'Liechtenstein': 'LIE',
 'Lithuania': 'LTU',
 'Luxembourg': 'LUX',
 'Macau': 'MAC',
 'Macedonia': 'MKD',
 'Madagascar': 'MDG',
 'Malawi': 'MWI',
 'Malaysia': 'MYS',
 'Maldives': 'MDV',
 'Mali': 'MLI',
 'Malta': 'MLT',
 'Marshall Islands': 'MHL',
 'Mauritania': 'MRT',
 'Mauritius': 'MUS',
 'Mexico': 'MEX',
 'Micronesia, Federated States of': 'FSM',
 'Moldova': 'MDA',
 'Monaco': 'MCO',
 'Mongolia': 'MNG',
 'Montenegro': 'MNE',
 'Morocco': 'MAR',
 'Mozambique': 'MOZ',
 'Namibia': 'NAM',
 'Nepal': 'NPL',
 'Netherlands': 'NLD',
 'New Caledonia': 'NCL',
 'New Zealand': 'NZL',
 'Nicaragua': 'NIC',
 'Nigeria': 'NGA',
 'Niger': 'NER',
 'Niue': 'NIU',
 'Northern Mariana Islands': 'MNP',
 'Norway': 'NOR',
 'Oman': 'OMN',
 'Pakistan': 'PAK',
 'Palau': 'PLW',
 'Panama': 'PAN',
 'Papua New Guinea': 'PNG',
 'Paraguay': 'PRY',
 'Peru': 'PER',
 'Philippines': 'PHL',
 'Poland': 'POL',
 'Portugal': 'PRT',
 'Puerto Rico': 'PRI',
 'Qatar': 'QAT',
 'Romania': 'ROU',
 'Russia': 'RUS',
 'Rwanda': 'RWA',
 'Saint Kitts and Nevis': 'KNA',
 'Saint Lucia': 'LCA',
 'Saint Martin': 'MAF',
 'Saint Pierre and Miquelon': 'SPM',
 'Saint Vincent and the Grenadines': 'VCT',
 'Samoa': 'WSM',
 'San Marino': 'SMR',
 'Sao Tome and Principe': 'STP',
 'Saudi Arabia': 'SAU',
 'Senegal': 'SEN',
 'Serbia': 'SRB',
 'Seychelles': 'SYC',
 'Sierra Leone': 'SLE',
 'Singapore': 'SGP',
 'Sint Maarten': 'SXM',
 'Slovakia': 'SVK',
 'Slovenia': 'SVN',
 'Solomon Islands': 'SLB',
 'Somalia': 'SOM',
 'South Africa': 'ZAF',
 'South Sudan': 'SSD',
 'Spain': 'ESP',
 'Sri Lanka': 'LKA',
 'Sudan': 'SDN',
 'Suriname': 'SUR',
 'Swaziland': 'SWZ',
 'Sweden': 'SWE',
 'Switzerland': 'CHE',
 'Syria': 'SYR',
 'Taiwan': 'TWN',
 'Tajikistan': 'TJK',
 'Tanzania': 'TZA',
 'Thailand': 'THA',
 'Timor-Leste': 'TLS',
 'Togo': 'TGO',
 'Tonga': 'TON',
 'Trinidad and Tobago': 'TTO',
 'Tunisia': 'TUN',
 'Turkey': 'TUR',
 'Turkmenistan': 'TKM',
 'Tuvalu': 'TUV',
 'Uganda': 'UGA',
 'Ukraine': 'UKR',
 'United Arab Emirates': 'ARE',
    'UAE': 'ARE',
 'United Kingdom': 'GBR',
    'UK': 'GBR',
 'United States': 'USA',
    'USA': 'USA',
 'Uruguay': 'URY',
 'Uzbekistan': 'UZB',
 'Vanuatu': 'VUT',
 'Venezuela': 'VEN',
 'Vietnam': 'VNM',
 'Virgin Islands': 'VGB',
 'West Bank': 'WBG',
 'Yemen': 'YEM',
 'Zambia': 'ZMB',
 'Zimbabwe': 'ZWE',
    'S. Korea': 'KOR'
}

# %%
country_df['iso_code'] = country_df['Country'].map(country_abbrev)
map_country_df = country_df.loc[~country_df['iso_code'].isna()]
map_country_df['death_rate'] = (100*map_country_df['Total Deaths']/map_country_df['Total Cases']).round(2)
map_country_df.head()
# Out:
#    Country  Total Cases  New Cases  Total Deaths  New Deaths  Total Recovered  \
# 1      USA    107194316     3387.0       1166818        37.0        105334686
# 2    India     44993080      292.0        531892        -1.0         44459040
# 3   France     40116548     2631.0        167508        28.0         39898866
# 4  Germany     38428685       -1.0        174352        -1.0         38240600
# 5   Brazil     37639324     1915.0        703399        15.0         36249161
#
#    New Recovered  Active Cases  Serious/Critical  Tot Cases/1M  Deaths/1M  \
# 1         4521.0      692812.0               841      320169.0     3485.0
# 2          220.0        2148.0                 0       31986.0      378.0
# 3         4905.0       50174.0               869      611677.0     2554.0
# 4           -1.0       13733.0                 0      458119.0     2078.0
# 5           -1.0      686764.0                 0      174779.0     3266.0
#
#    Total Tests  Tests/1M  Population      Continent  %Inc Cases  %Inc Deaths  \
# 1   1180560088   3526110   334805269  North America    0.003160     0.003171
# 2    930797975    661721  1406631776           Asia    0.000649    -0.000188
# 3    271490188   4139547    65584518         Europe    0.006558     0.016716
# 4    122332384   1458359    83883596         Europe   -0.000003    -0.000574
# 5     63776166    296146   215353593  South America    0.005088     0.002133
#
#    %Inc Recovered iso_code  death_rate
# 1        0.004292      USA        1.09
# 2        0.000495      IND        1.18
# 3        0.012294      FRA        0.42
# 4       -0.000003      DEU        0.45
# 5       -0.000003      BRA        1.87

# %%
fig = go.Figure(data=go.Choropleth(
    locations=map_country_df['iso_code'],
    z=map_country_df['Total Cases'].astype(float),
    colorscale="Reds",
    colorbar_title="Total"
))

fig.update_layout(
    geo=dict(
        showframe=False,
        showcoastlines=False,
        projection_type='equirectangular'
    ),
    title={'text': f"Total COVID Cases in the World", 'x': 0.5,
                         'xanchor': 'center', 'font': {'size': 16}}
)

fig.show()
# Out:
# <div>                            <div id="835ca3f2-6aa7-45ec-a808-883dea40db73" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("835ca3f2-6aa7-45ec-a808-883dea40db73")) {                    Plotly.newPlot(                        "835ca3f2-6aa7-45ec-a808-883dea40db73",                        [{"colorbar": {"title": {"text": "Total"}}, "colorscale": [[0.0, "rgb(255,245,240)"], [0.125, "rgb(254,224,210)"], [0.25, "rgb(252,187,161)"], [0.375, "rgb(252,146,114)"], [0.5, "rgb(251,106,74)"], [0.625, "rgb(239,59,44)"], [0.75, "rgb(203,24,29)"], [0.875, "rgb(165,15,21)"], [1.0, "rgb(103,0,13)"]], "locations": ["USA", "IND", "FRA", "DEU", "BRA", "JPN", "KOR", "ITA", "GBR", "RUS", "TUR", "ESP", "AUS", "VNM", "MEX", "IRN", "IDN", "POL", "COL", "GRC", "AUT", "PRT", "UKR", "CHL", "MYS", "ISR", "BEL", "THA", "CAN", "CZE", "CHE", "PHL", "ZAF", "ROU", "DNK", "HKG", "SWE", "SRB", "SGP", "IRQ", "NZL", "HUN", "BGD", "GEO", "JOR", "IRL", "PAK", "NOR", "FIN", "KAZ", "SVN", "LTU", "BGR", "MAR", "HRV", "GTM", "LBN", "CRI", "BOL", "TUN", "CUB", "ARE", "ECU", "PAN", "URY", "MNG", "NPL", "BLR", "LVA", "SAU", "AZE", "PRY", "BHR", "LKA", "KWT", "DOM", "MDA", "EST", "VEN", "EGY", "QAT", "LBY", "ETH", "HND", "ARM", "BIH", "OMN", "ZMB", "KEN", "ALB", "BWA", "LUX", "MNE", "DZA", "NGA", "ZWE", "UZB", "MOZ", "AFG", "LAO", "ISL", "KGZ", "SLV", "TTO", "MDV", "GHA", "NAM", "UGA", "JAM", "KHM", "RWA", "CMR", "MLT", "BRB", "AGO", "SEN", "MWI", "SUR", "NCL", "PYF", "GUY", "BLZ", "FJI", "MDG", "SDN", "CPV", "MRT", "BTN", "BDI", "SYC", "GAB", "AND", "PNG", "ABW", "TZA", "MUS", "TGO", "GIN", "IMN", "LSO", "HTI", "MLI", "CYM", "LCA", "BEN", "SOM", "SLB", "SMR", "TLS", "BFA", "GIB", "GRD", "BMU", "NIC", "SSD", "TJK", "GNQ", "TON", "MCO", "WSM", "MHL", "DMA", "DJI", "MAF", "VUT", "GRL", "YEM", "SXM", "NER", "GNB", "COM", "ATG", "LBR", "SLE", "TCD", "VGB", "COK", "PLW", "KIR", "AIA", "TUV", "NIU"], "type": "choropleth", "z": [107194316.0, 44993080.0, 40116548.0, 38428685.0, 37639324.0, 33803572.0, 31904667.0, 25879984.0, 24618436.0, 22949243.0, 17232066.0, 13890555.0, 11653091.0, 11618184.0, 7627255.0, 7612234.0, 6810417.0, 6517448.0, 6369916.0, 6086580.
0, 138.0, 396.0, 113.0, 238.0, 165.0, 225.0, 138.0, 125.0, 183.0, 13.0, 67.0, 31.0, 17.0, 74.0, 189.0, 63.0, 14.0, 21.0, 2159.0, 92.0, 312.0, 177.0, 161.0, 146.0, 295.0, 126.0, 194.0, 64.0, 2.0, 9.0, 24.0, 12.0, -1.0, -1.0]}],                        {"geo": {"projection": {"type": "equirectangular"}, "showcoastlines": false, "showframe": false}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aa ...

# %%
fig = go.Figure(data=go.Choropleth(
    locations=map_country_df['iso_code'],
    z=map_country_df['death_rate'].astype(float),
    colorscale="Reds",
    colorbar_title="Percentage"
))

fig.update_layout(
    geo=dict(
        showframe=False,
        showcoastlines=False,
        projection_type='equirectangular'
    ),
    title={'text': f"Death Rate of Different Countries in the World", 'x': 0.5,
                         'xanchor': 'center', 'font': {'size': 16}}
)

fig.show()
# Out:
# <div>                            <div id="aaa482f9-4480-4e41-b9fa-53b252072737" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("aaa482f9-4480-4e41-b9fa-53b252072737")) {                    Plotly.newPlot(                        "aaa482f9-4480-4e41-b9fa-53b252072737",                        [{"colorbar": {"title": {"text": "Percentage"}}, "colorscale": [[0.0, "rgb(255,245,240)"], [0.125, "rgb(254,224,210)"], [0.25, "rgb(252,187,161)"], [0.375, "rgb(252,146,114)"], [0.5, "rgb(251,106,74)"], [0.625, "rgb(239,59,44)"], [0.75, "rgb(203,24,29)"], [0.875, "rgb(165,15,21)"], [1.0, "rgb(103,0,13)"]], "locations": ["USA", "IND", "FRA", "DEU", "BRA", "JPN", "KOR", "ITA", "GBR", "RUS", "TUR", "ESP", "AUS", "VNM", "MEX", "IRN", "IDN", "POL", "COL", "GRC", "AUT", "PRT", "UKR", "CHL", "MYS", "ISR", "BEL", "THA", "CAN", "CZE", "CHE", "PHL", "ZAF", "ROU", "DNK", "HKG", "SWE", "SRB", "SGP", "IRQ", "NZL", "HUN", "BGD", "GEO", "JOR", "IRL", "PAK", "NOR", "FIN", "KAZ", "SVN", "LTU", "BGR", "MAR", "HRV", "GTM", "LBN", "CRI", "BOL", "TUN", "CUB", "ARE", "ECU", "PAN", "URY", "MNG", "NPL", "BLR", "LVA", "SAU", "AZE", "PRY", "BHR", "LKA", "KWT", "DOM", "MDA", "EST", "VEN", "EGY", "QAT", "LBY", "ETH", "HND", "ARM", "BIH", "OMN", "ZMB", "KEN", "ALB", "BWA", "LUX", "MNE", "DZA", "NGA", "ZWE", "UZB", "MOZ", "AFG", "LAO", "ISL", "KGZ", "SLV", "TTO", "MDV", "GHA", "NAM", "UGA", "JAM", "KHM", "RWA", "CMR", "MLT", "BRB", "AGO", "SEN", "MWI", "SUR", "NCL", "PYF", "GUY", "BLZ", "FJI", "MDG", "SDN", "CPV", "MRT", "BTN", "BDI", "SYC", "GAB", "AND", "PNG", "ABW", "TZA", "MUS", "TGO", "GIN", "IMN", "LSO", "HTI", "MLI", "CYM", "LCA", "BEN", "SOM", "SLB", "SMR", "TLS", "BFA", "GIB", "GRD", "BMU", "NIC", "SSD", "TJK", "GNQ", "TON", "MCO", "WSM", "MHL", "DMA", "DJI", "MAF", "VUT", "GRL", "YEM", "SXM", "NER", "GNB", "COM", "ATG", "LBR", "SLE", "TCD", "VGB", "COK", "PLW", "KIR", "AIA", "TUV", "NIU"], "type": "choropleth", "z": [1.09, 1.18, 0.42, 0.45, 1.87, 0.22, 0.11, 0.74, 0.92, 1.74, 0.59, 0.87, 0.18, 0.37, 4.38, 1.92, 2.38, 1.84, 2.24, 0.61, 0.37, 0.48, 2.02, 1.22, 0.73, 0.26, 0.72, 0.72, 1.13, 0.92, 0.33, 1.6, 2.52, 2.0, 0.27, 0.48, 0.9, 0.71, 0.07, 1.03, 0.19, 2.22, 1.44, 0.93, 0.81, 0.53, 1.94, 0.37, 0.66, 0.98, 0.53, 0.73, 2.94, 1.28, 1.43, 1.61, 0.88, 0.76, 1.86, 2.55, 0.77, 0.22, 3.39, 0.83, 0.73, 0.22, 1.2, 0.72, 0.65, 1.15, 1.24, 2.46, 0.22, 2.51, 0.39, 0.66, 1.95, 0.48, 1.06, 4.77, 0.13, 1.27, 1.51, 2.35, 1.95, 4.06, 1.16, 1.18, 1.66, 1.08, 0.85, 0.39, 0.97, 2.53, 1.18, 2.15, 0.65, 0.96, 3.56, 0.35, 0.11, 1.45, 2.1, 2.29, 0.17, 0.85, 2.39, 2.13, 2.29, 2.2, 1.1, 1.58, 0.71, 0.55, 1.84, 2.21, 3.03, 1.7, 0.39, 0.83, 1.77, 0.97, 1.28, 2.09, 7.89, 0.65, 1.56, 0.03, 0.07, 0.34, 0.63, 0.34, 1.43, 0.53, 1.96, 2.47, 0.73, 1.21, 0.31, 2.08, 2.51, 2.24, 0.12, 1.36, 0.58, 4.98, 0.62, 0.51, 0.59, 1.8, 0.55, 1.21, 0.87, 1.22, 0.75, 0.7, 1.06, 0.08, 0.4, 0.18, 0.11, 0.47, 1.2, 0.51, 0.12, 0.18, 18.07, 0.83, 3.14, 1.84, 1.77, 1.6, 3.65, 1.62, 2.52, 0.88, 0.03, 0.15, 0.48, 0.31, -0.04, -0.12]}],                        {"geo": {"projection": {"type": "equirectangular"}, "showcoastlines": false, "showframe": false}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": ...

# %%
fig = go.Figure(data=go.Choropleth(
    locations=map_country_df['iso_code'],
    z=map_country_df['Deaths/1M'].astype(float),
    colorscale="Reds",
    colorbar_title="Per Million"
))

fig.update_layout(
    geo=dict(
        showframe=False,
        showcoastlines=False,
        projection_type='equirectangular'
    ),
    title={'text': f"Deaths Per Million in the World", 'x': 0.5,
                         'xanchor': 'center', 'font': {'size': 16}}
)

fig.show()
# Out:
# <div>                            <div id="19cff959-7b07-4878-9ba2-5ac75853fc6a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("19cff959-7b07-4878-9ba2-5ac75853fc6a")) {                    Plotly.newPlot(                        "19cff959-7b07-4878-9ba2-5ac75853fc6a",                        [{"colorbar": {"title": {"text": "Per Million"}}, "colorscale": [[0.0, "rgb(255,245,240)"], [0.125, "rgb(254,224,210)"], [0.25, "rgb(252,187,161)"], [0.375, "rgb(252,146,114)"], [0.5, "rgb(251,106,74)"], [0.625, "rgb(239,59,44)"], [0.75, "rgb(203,24,29)"], [0.875, "rgb(165,15,21)"], [1.0, "rgb(103,0,13)"]], "locations": ["USA", "IND", "FRA", "DEU", "BRA", "JPN", "KOR", "ITA", "GBR", "RUS", "TUR", "ESP", "AUS", "VNM", "MEX", "IRN", "IDN", "POL", "COL", "GRC", "AUT", "PRT", "UKR", "CHL", "MYS", "ISR", "BEL", "THA", "CAN", "CZE", "CHE", "PHL", "ZAF", "ROU", "DNK", "HKG", "SWE", "SRB", "SGP", "IRQ", "NZL", "HUN", "BGD", "GEO", "JOR", "IRL", "PAK", "NOR", "FIN", "KAZ", "SVN", "LTU", "BGR", "MAR", "HRV", "GTM", "LBN", "CRI", "BOL", "TUN", "CUB", "ARE", "ECU", "PAN", "URY", "MNG", "NPL", "BLR", "LVA", "SAU", "AZE", "PRY", "BHR", "LKA", "KWT", "DOM", "MDA", "EST", "VEN", "EGY", "QAT", "LBY", "ETH", "HND", "ARM", "BIH